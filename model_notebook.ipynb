# %%
# !nvidia-smi
# Out:
# Sat May  6 09:52:10 2023
# +-----------------------------------------------------------------------------+
# | NVIDIA-SMI 525.85.12    Driver Version: 525.85.12    CUDA Version: 12.0     |
# |-------------------------------+----------------------+----------------------+
# | GPU  Name        Persistence-M| Bus-Id        Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp  Perf  Pwr:Usage/Cap|         Memory-Usage | GPU-Util  Compute M. |
# |                               |                      |               MIG M. |
# |===============================+======================+======================|
# |   0  Tesla T4            Off  | 00000000:00:04.0 Off |                    0 |
# | N/A   39C    P8    11W /  70W |      0MiB / 15360MiB |      0%      Default |
# |                               |                      |                  N/A |
# +-------------------------------+----------------------+----------------------+
#
# ...

# %%
# !pip install ultralytics
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 565.5/565.5 kB 39.0 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 203.1/203.1 kB 26.0 MB/s eta 0:00:00
# ...

# %%
from IPython import display
display.clear_output()

import ultralytics
ultralytics.checks()
# Out:
# Ultralytics YOLOv8.0.93 🚀 Python-3.10.11 torch-2.0.0+cu118 CUDA:0 (Tesla T4, 15102MiB)
# Setup complete ✅ (2 CPUs, 12.7 GB RAM, 23.4/78.2 GB disk)

# %%
from ultralytics import YOLO
# !yolo detect train data=/content/drive/MyDrive/VideoToPhoto/data_custom.yaml model=yolov8m.pt epochs=80 imgsz=640 project=/content/drive/MyDrive/VideoToPhoto/results
# Out:
# ...
# 100% 49.7M/49.7M [00:02<00:00, 18.4MB/s]
# Ultralytics YOLOv8.0.93 🚀 Python-3.10.11 torch-2.0.0+cu118 CUDA:0 (Tesla T4, 15102MiB)
# ...

# %%
# !yolo detect predict model = /content/drive/MyDrive/VideoToPhoto/results/train4/weights/best.pt source = /content/drive/MyDrive/VideoToPhoto/VID_20230506_153321[1].mp4 save = True
# Out:
# Ultralytics YOLOv8.0.93 🚀 Python-3.10.11 torch-2.0.0+cu118 CUDA:0 (Tesla T4, 15102MiB)
# Model summary (fused): 218 layers, 25841497 parameters, 0 gradients, 78.7 GFLOPs
#
# video 1/1 (1/741) /content/drive/MyDrive/VideoToPhoto/VID_20230506_153321[1].mp4: 384x640 1 human, 63.6ms
# video 1/1 (2/741) /content/drive/MyDrive/VideoToPhoto/VID_20230506_153321[1].mp4: 384x640 1 human, 25.8ms
# video 1/1 (3/741) /content/drive/MyDrive/VideoToPhoto/VID_20230506_153321[1].mp4: 384x640 1 human, 25.8ms
# video 1/1 (4/741) /content/drive/MyDrive/VideoToPhoto/VID_20230506_153321[1].mp4: 384x640 1 human, 25.8ms
# video 1/1 (5/741) /content/drive/MyDrive/VideoToPhoto/VID_20230506_153321[1].mp4: 384x640 1 human, 25.8ms
# video 1/1 (6/741) /content/drive/MyDrive/VideoToPhoto/VID_20230506_153321[1].mp4: 384x640 1 human, 25.8ms
# video 1/1 (7/741) /content/drive/MyDrive/VideoToPhoto/VID_20230506_153321[1].mp4: 384x640 1 human, 25.8ms
# ...
